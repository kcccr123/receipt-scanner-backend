# %%
import os
import torch
import pandas as pd
import callbacks
import data
import dataUtils as du
import image
import metric
import modelArc
import trainer
import tqdm
from config import ConfigFile
from datetime import datetime

# %%
#load data
#Specify path to main database
data_dir = r"D:\photos\RCNN4\BBOXES"
model_path = r"D:\Projects\reciept-scanner\RCNN\models"
database, vocab, max_len = [], set(), 0

largest_index = 492


print("dataset of " + str(largest_index) + " images")

for id in range(0, largest_index+1):

    img_path = os.path.join(data_dir, str(id) + ".jpg").replace("\\","/")
    
    if os.path.exists(img_path):

        with open(os.path.join(data_dir, str(id) + ".txt").replace("\\","/"), 'r') as file:
            ground_truths = [line.strip() for line in file.readlines()]
        
        for line in ground_truths:
            if not line.strip() == '':
                label = line.rstrip("\n")
                database.append([img_path, label])
                vocab.update(list(label))
                max_len = max(max_len, len(label))
    else:
        print("image with index " + str(id) + " do not exist")

print("database, vocab, max_len, complete")
print(database)
# Out:
# dataset of 492 images
# image with index 187 do not exist
# image with index 190 do not exist
# image with index 194 do not exist
# image with index 197 do not exist
# image with index 199 do not exist
# image with index 354 do not exist
# image with index 366 do not exist
# image with index 370 do not exist
# image with index 372 do not exist
# image with index 381 do not exist
# image with index 393 do not exist
# database, vocab, max_len, complete
# [['D:/photos/RCNN4/BBOXES/0.jpg', 'AMOUNT'], ['D:/photos/RCNN4/BBOXES/0.jpg', '$23.99'], ['D:/photos/RCNN4/BBOXES/1.jpg', 'SHINHO SOY BEAN PASTE'], ['D:/photos/RCNN4/BBOXES/1.jpg', '2 @ $1.39ea.'], ['D:/photos/RCNN4/BBOXES/1.jpg', 'W $2.78'], ['D:/photos/RCNN4/BBOXES/2.jpg', 'SALE) PREVIOUSLY FZ BLACK COO'], ['D:/photos/RCNN4/BBOXES/2.jpg', '1.220 kg @ $15.17/kg'], ['D:/photos/RCNN4/BBOXES/2.jpg', 'W $18.51'], ['D:/photos/RCNN4/BBOXES/3.jpg', '(SALE) STRAWBERRY'], ['D:/photos/RCNN4/BBOXES/3.jpg', '576431'], ['D:/photos/RCNN4/BBOXES/3.jpg', '2 @2/$6.00'], ['D:/photos/RCNN4/BBOXES/3.jpg', 'W $6.00'], ['D:/photos/RCNN4/BBOXES/4.jpg', 'SEAFOOD MUSHROOM 2 @ $1.99ea.'], ['D:/photos/RCNN4/BBOXES/4.jpg', 'W $3.98'], ['D:/photos/RCNN4/BBOXES/5.jpg', 'GRAPE TOMATO'], ['D:/photos/RCNN4/BBOXES/5.jpg', 'W $6.88'], ['D:/photos/RCNN4/BBOXES/6.jpg', 'TOTAL'], ['D:/photos/RCNN4/BBOXES/6.jpg', '$38.15'], ['D:/photos/RCNN4/BBOXES/7.jpg', 'Total:'], ['D:/photos/RCNN4/BBOXES/7.jpg', '$18.19 $18.19'], ['D:/photos/RCNN4/BBOXES/8.jpg', 'Cilantro 1@$0.99/each'], ['D:/photos/RCNN4/BBOXES/8.jpg', '$0.99'], ['D:/photos/RCNN4/BBOXES/9.jpg', 'Loose Beets'], ['D:/photos/RCNN4/BBOXES/9.jpg', '2.24 lb @ $1.59/lb'], ['D:/photos/RCNN4/BBOXES/9.jpg', '$3.56'], ['D:/photos/RCNN4/BBOXES/10.jpg', 'HH Tomato'], ['D:/photos/RCNN4/BBOXES/10.jpg', '328 lb @ $0.99/lb'], ['D:/photos/RCNN4/BBOXES/10.jpg', '$3.25'], ['D:/photos/RCNN4/BBOXES/11.jpg', 'Fuji Apple'], ['D:/photos/RCNN4/BBOXES/11.jpg', '1.87 lb @ $1.49/lb'], ['D:/photos/RCNN4/BBOXES/11.jpg', '$2.79'], ['D:/photos/RCNN4/BBOXES/12.jpg', 'Celery'], ['D:/photos/RCNN4/BBOXES/12.jpg', '1 85 lb @ $1.49/lb'], ['D:/photos/RCNN4/BBOXES/12.jpg', '$2.76'], ['D:/photos/RCNN4/BBOXES/13.jpg', 'Cauliflower'], ['D:/photos/RCNN4/BBOXES/13.jpg', '$1 19/h'], ['D:/photos/RCNN4/BBOXES/13.jpg', '$4.84'], ['D:/photos/RCNN4/BBOXES/14.jpg', 'Sub-Total:'], ['D:/photos/RCNN4/BBOXES/14.jpg', '$18.19'], ['D:/photos/RCNN4/BBOXES/15.jpg', '(SALE) CHINESE WHITE RADISH'], ['D:/photos/RCNN4/BBOXES/15.jpg', '1.005 kg @ $1.70/kg'], ['D:/photos/RCNN4/BBOXES/15.jpg', 'W $1.71'], ['D:/photos/RCNN4/BBOXES/16.jpg', '(SALE) CHINESE WHITE RADISH'], ['D:/photos/RCNN4/BBOXES/16.jpg', '1.035 kg @ $1.70/kg'], ['D:/photos/RCNN4/BBOXES/16.jpg', 'W $1.76'], ['D:/photos/RCNN4/BBOXES/17.jpg', 'SEA'], ['D:/photos/RCNN4/BBOXES/17.jpg', '(SALE) Z FISH TOFU'], ['D:/photos/RCNN4/BBOXES/17.jpg', '4 @ $4.98ea.'], ['D:/photos/RCNN4/BBOXES/17.jpg', 'W $19.92'], ['D:/photos/RCNN4/BBOXES/18.jpg', 'SHINHO SOY BEAN PASTE 2 @ $1.3988.'], ['D:/photos/RCNN4/BBOXES/18.jpg', 'U $2.78'], ['D:/photos/RCNN4/BBOXES/19.jpg', 'GRAND MAPLE VINEGAR'], ['D:/photos/RCNN4/BBOXES/19.jpg', 'W $1.99'], ['D:/photos/RCNN4/BBOXES/20.jpg', 'CHINESE EGGPLANT'], ['D:/photos/RCNN4/BBOXES/20.jpg', '2.095 kg @ $5.49/kg'], ['D:/photos/RCNN4/BBOXES/20.jpg', 'W $11.50'], ['D:/photos/RCNN4/BBOXES/21.jpg', '(SALE) KABOCHA 1.040 kg @ $2.16/kg'], ['D:/photos/RCNN4/BBOXES/21.jpg', 'W $2.25'], ['D:/photos/RCNN4/BBOXES/22.jpg', 'POTATOES'], ['D:/photos/RCNN4/BBOXES/22.jpg', '2.265 kg @ $2.18/kg'], ['D:/photos/RCNN4/BBOXES/22.jpg', 'W $4.94'], ['D:/photos/RCNN4/BBOXES/23.jpg', '(MEMBERS) VINE TOMATOES 1.630 kg @ $2.80/kg'], ['D:/photos/RCNN4/BBOXES/23.jpg', 'W $4.56'], ['D:/photos/RCNN4/BBOXES/24.jpg', 'JAPANESE SWEET POTATO'], ['D:/photos/RCNN4/BBOXES/24.jpg', '1.075 kg @ $4.39/kg'], ['D:/photos/RCNN4/BBOXES/24.jpg', 'W $4.72'], ['D:/photos/RCNN4/BBOXES/25.jpg', 'SUY BEAN SPROUT'], ['D:/photos/RCNN4/BBOXES/25.jpg', 'W $1.29'], ['D:/photos/RCNN4/BBOXES/26.jpg', 'T&T TRADITIONAL TOFU'], ['D:/photos/RCNN4/BBOXES/26.jpg', '2 @ $2.79ea.'], ['D:/photos/RCNN4/BBOXES/26.jpg', 'W $5.58'], ['D:/photos/RCNN4/BBOXES/27.jpg', 'TOTAL'], ['D:/photos/RCNN4/BBOXES/27.jpg', '$63.00'], ['D:/photos/RCNN4/BBOXES/28.jpg', 'ECCO Soft 7 W Lace up LEA'], ['D:/photos/RCNN4/BBOXES/28.jpg', '1'], ['D:/photos/RCNN4/BBOXES/28.jpg', '$230.00'], ['D:/photos/RCNN4/BBOXES/29.jpg', 'ECCO Midsole Cleaning Kit'], ['D:/photos/RCNN4/BBOXES/29.jpg', '1 ...

# %%
#create data loaders
model_config = ConfigFile(name = "CRNN1", path = model_path, lr=0.0003, bs=32)

model_config.vocab = "".join(vocab)
model_config.max_txt_len = max_len
model_config.save()

dataset_loader = data.DataLoader(dataset = database, batch_size = model_config.batch_size, 
                                 data_preprocessors = [image.ImageReader(image.CVImage)], 
                                 transformers = [du.ImageResizer(model_config.width, model_config.height), du.LabelIndexer(model_config.vocab), 
                                                 du.LabelPadding(padding_value = len(model_config.vocab), max_word_len = max_len)])#, du.ImageShowCV2()


train_set, val_set = dataset_loader.split(split = 0.7)

train_set.augmentors = [
    du.RandomBrightness(),
    du.RandomErodeDilate(),
    du.RandomSharpen(),
    du.RandomRotate(angle=10),
    ]
# Out:
# config saved toD:/Projects/reciept-scanner/RCNN/models/202407100110

# %%
#initialize model, optimizer, and loss
model = modelArc.CRNN(len(model_config.vocab))
loss = trainer.CTCLoss(blank = len(model_config.vocab))
optimizer = torch.optim.Adam(model.parameters(), lr=model_config.lr)

if torch.cuda.is_available():
    model = model.cuda()
    print("CUDA Enabled...Training On GPU")
# Out:
# CUDA Enabled...Training On GPU

# %%
#initialze callbacks and trainer
earlystop = callbacks.EarlyStopping(monitor = "val_CER", patience = 10, verbose = True)
ckpt = callbacks.ModelCheckpoint((model_config.model_path + "/model.pt").replace("\\","/"), monitor = "val_CER", verbose = True)
tracker = callbacks.TensorBoard((model_config.model_path + "/logs").replace("\\","/"))
auto_lr = callbacks.ReduceLROnPlateau(monitor = "val_CER", factor=0.9, patience = 10, verbose = True)
save_model = callbacks.Model2onnx(saved_model_path = (os.path.join(model_path, datetime.strftime(datetime.now(), "%Y%m%d%H%M"),"model.pt").replace("\\","/")), input_shape = (1, model_config.height, model_config.width, 3), verbose = True, metadata = {"vocab": model_config.vocab})


train_struct = trainer.Trainer(model, optimizer, loss, metrics = [metric.CERMetric(model_config.vocab), metric.WERMetric(model_config.vocab)])

# %%
#train
train_struct.run(train_set, val_set, epochs=2, callbacks = [ckpt, tracker, auto_lr, save_model])#earlystop,

train_set.to_csv(os.path.join(model_config.model_path, "train.csv").replace("\\","/"))
val_set.to_csv(os.path.join(model_config.model_path, "val.csv").replace("\\","/"))
# Out:
#  Iters    Elapsed Time      Speed
#  0/25           -             -
# Epoch 1:    0.0% |                                                             |c:\Users\Gary Guo\anaconda3\envs\scannerCRNN\Lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# c:\Users\Gary Guo\anaconda3\envs\scannerCRNN\Lib\site-packages\torch\autograd\graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#  Iters    Elapsed Time      Speed     loss     CER    WER    lr
#  1/25   00:00:00<00:00:15  1.52it/s  37.9856  5.1628  1.0  0.0003
# Epoch 1:    4.0% |██                                                           | Iters    Elapsed Time      Speed     loss     CER     WER      lr
#  3/25   00:00:01<00:00:07  2.96it/s  34.5057  4.3964  1.0056  0.0003
# Epoch 1:   12.0% |███████                                                      | Iters    Elapsed Time      Speed     loss     CER     WER      lr
#  5/25   00:00:01<00:00:05  3.82it/s  35.4981  3.9163  1.0065  0.0003
# Epoch 1:   20.0% |████████████                                                 | Iters    Elapsed Time      Speed     loss     CER     WER      lr
#  7/25   00:00:01<00:00:04  4.28it/s  34.9156  3.2193  1.0046  0.0003
# Epoch 1:   28.0% |█████████████████                                            | Iters    Elapsed Time      Speed     loss     CER     WER      lr
#  9/25   00:00:01<00:00:03  4.64it/s  34.1723  2.7283  1.0036  0.0003
# Epoch 1:   36.0% |█████████████████████                                        | Iters    Elapsed Time      Speed     loss     CER     WER      lr
#  11/25  00:00:02<00:00:02  4.97it/s  33.5278  2.4115  1.0015  0.0003
# Epoch 1:   44.0% |██████████████████████████                                   | Iters    Elapsed Time      Speed     loss     CER    WER      lr
#  13/25  00:00:02<00:00:02  5.25it/s  32.5789  2.193  1.0013  0.0003
# Epoch 1:   52.0% |███████████████████████████████                              | Iters    Elapsed Time      Speed     loss    CER     WER      lr
#  15/25  00:00:02<00:00:01  5.51it/s  31.777  2.0339  1.0011  0.0003
# Epoch 1:   60.0% |████████████████████████████████████                         | Iters    Elapsed Time      Speed     loss     CER     WER     lr
#  17/25  00:00:03<00:00:01  5.64it/s  30.5679  1.9123  1.001  0.0003
# Epoch 1:   68.0% |█████████████████████████████████████████                    | Iters    Elapsed Time      Speed     loss     CER     WER      lr
#  19/25  00:00:03<00:00:01  5.86it/s  29.4539  1.8162  1.0009  0.0003
# Epoch 1:   76.0% |██████████████████████████████████████████████               | Iters    Elapsed Time      Speed     loss     CER     WER      lr
#  21/25  00:00:03<00:00:00  5.92it/s  28.2274  1.7385  1.0008  0.0003
# Epoch 1:   84.0% |███████████████████████████████████████████████████          | Iters    Elapsed Time      Speed     loss     CER     WER      lr
#  23/25  00:00:03<00:00:00  6.09it/s  26.8605  1.6743  1.0007  0.0003
# Epoch 1:   92.0% |████████████████████████████████████████████████████████     | Iters    Elapsed Time      Speed     loss     CER     WER      lr
#  25/25  00:00:04<00:00:00  6.21it/s  25.5497  1.6203  1.0007  0.0003
# Epoch 1:  100.0% |█████████████████████████████████████████████████████████████| Iters    Elapsed Time      Speed     loss     CER     WER      lr
#  25/25  00:00:04<00:00:00  6.21it/s  25.5497  1.6203  1.0007  0.0003
# Epoch 1:  100.0% |█████████████████████████████████████████████████████████████| Iters    Elapsed Time      Speed
#  0/11           -             -
# Description   0.0% |                                                           | Iters    Elapsed Time       Speed    val_loss  val_CER  val_WER
#  3/11   00:00:00<00:00:00  12.67it/s   6.5448     1.0      1.0
# Epoch 1:   27.3% |████████████████                                             | Iters    Elapsed Time       Speed    val_loss  val_CER  val_WER
#  6/11   00:00:00<00:00:00  13.38it/s   7.1918     1.0      1.0
# Epoch 1:   54.5% |█████████████████████████████████                            | Iters    Elapsed Time       Speed    val_loss  val_CER  val_WER
#  10/11  00:00:00<00:00:00  13.82it/s   7.1067     1.0      1.0
# Epoch 1:   90.9% |███████████████████████████████████████████████████████      | Iters    Elapsed Time       Speed    val_loss  val_CER  val_WER
#  11/11  00:00:00<00:00:00  13.98it/s   6.9973     1.0      1.0
# Epoch 1:  100.0% |█████████████████████████████████████████████████████████████|INFO:ModelCheckpoint:Epoch 1: val_CER improved from inf to 1.00000, saving model to D:\Projects\reciept-scanner\RCNN\models\202407100110\model.pt
#  Iters    Elapsed Time      Speed
#  0/25           -             -
# Epoch 2:    0.0% |                                                             | Iters    Elapsed Time      Speed     loss   CER  WER    lr
#  2/25   00:00:00<00:00:02  9.60it/s  8.4165  1.0  1.0  0.0003
# Epoch 2:    8.0% |████                                                         | Iters    Elapsed Time      Speed     loss   CER  WER    lr
#  4/25   00:00:00<00:00:02  9.29it/s  7.3539  1.0  1.0  0.0003
# Epoch 2:   16.0% |█████████                                                    | Iters    Elapsed Time      Speed     loss   CER  WER    lr
#  6/25   00:00:00<00:00:02  9.00it/s  6.6505  1.0  1.0  0.0003
# Epoch 2:   24.0% |██████████████                                               | Iters    Elapsed Time      Speed     loss   CER  WER    lr
#  8/25   00:00:00<00:00:01  9.01it/s  6.1835  1.0  1.0  0.0003
# Epoch 2:   32.0% |███████████████████                                          | Iters    Elapsed Time      Speed     loss   CER  WER    lr
#  10/25  00:00:01<00:00:01  8.89it/s  5.8493  1.0  1.0  0.0003
# Epoch 2:   40.0% |████████████████████████                                     | Iters    Elapsed Time      Speed    loss   CER  WER    lr
#  12/25  00:00:01<00:00:01  8.95it/s  5.603  1.0  1.0  0.0003
# Epoch 2:   48.0% |█████████████████████████████                                | Iters    Elapsed Time      Speed     loss   CER  WER    lr
#  14/25  00:00:01<00:00:01  8.74it/s  5.4733  1.0  1.0  0.0003
# Epoch 2:   56.0% |██████████████████████████████████                           | Iters    Elapsed Time      Speed     loss   CER  WER    lr
#  17/25  00:00:01<00:00:00  9.03it/s  5.2804  1.0  1.0  0.0003
# Epoch 2:   68.0% |█████████████████████████████████████████                    | Iters    Elapsed Time      Speed    loss   CER  WER    lr
#  19/25  00:00:02<00:00:00  9.06it/s  5.207  1.0  1.0  0.0003
# Epoch 2:   76.0% |██████████████████████████████████████████████               | Iters    Elapsed Time      Speed     loss   CER  WER    lr
#  21/25  00:00:02<00:00:00  8.98it/s  5.1472  1.0  1.0  0.0003
# Epoch 2:   84.0% |███████████████████████████████████████████████████          | Iters    Elapsed Time      Speed     loss   CER  WER    lr
#  23/25  00:00:02<00:00:00  8.83it/s  5.0755  1.0  1.0  0.0003
# Epoch 2:   92.0% |████████████████████████████████████████████████████████     | Iters    Elapsed Time      Speed     loss   CER  WER    lr
#  25/25  00:00:02<00:00:00  9.02it/s  5.0381  1.0  1.0  0.0003
# Epoch 2:  100.0% |█████████████████████████████████████████████████████████████| Iters    Elapsed Time      Speed
#  0/11           -             -
# Description   0.0% |                                                           | Iters    Elapsed Time       Speed    val_loss  val_CER  val_WER
#  8/11   00:00:00<00:00:00  38.02it/s   4.6476     1.0      1.0
# Epoch 2:   72.7% |████████████████████████████████████████████                 | Iters    Elapsed Time       Speed    val_loss  val_CER  val_WER
#  11/11  00:00:00<00:00:00  40.10it/s   4.6743     1.0      1.0
# Epoch 2:  100.0% |█████████████████████████████████████████████████████████████|
# 128
# torch.Size([1, 32, 128, 3])
# c:\Users\Gary Guo\anaconda3\envs\scannerCRNN\Lib\site-packages\torch\onnx\symbolic_opset9.py:4661: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# INFO:Model2onnx:Model saved to D:\Projects\reciept-scanner\RCNN\models\202407100110\model.onnx
